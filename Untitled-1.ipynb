# %%
pip install pandas plotly streamlit-echarts pillow wordcloud pyecharts matplotlib numpy folium geopy openpyxl geopandas streamlit-extras streamlit-folium
# Out:
# ...
#   Using cached plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached streamlit_echarts-0.4.0-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached wordcloud-1.9.4-cp310-cp310-win_amd64.whl.metadata (3.5 kB)
# ...
#
#   Using cached pyecharts-2.0.8-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached matplotlib-3.10.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached streamlit_extras-0.6.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached streamlit_folium-0.24.0-py3-none-any.whl.metadata (413 bytes)
# ...
#   Using cached simplejson-3.20.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached prettytable-3.16.0-py3-none-any.whl.metadata (33 kB)
# ...
